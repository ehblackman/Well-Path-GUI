# %%
import Point_XYZ_Package as xyz

def main():
  # GUI data import
  collar_data, survey_data, sample_data, geology_data = xyz.main()

  # Data stuff, manipulation, calculations etc
  surveys = xyz.import_survey(survey_data)
  collars = xyz.import_collar(collar_data, surveys)  
  samples = xyz.import_sample(sample_data, collars)
  tops = xyz.import_geology(geology_data, collars)

  # Plotting
  xyz.plot(collars, tops)
  # Saving
  print(collars, surveys, samples, tops)
  return collars, surveys, samples, tops
  

if __name__ == "__main__":
    main()
# Out:
# /home/edwardblackman/WELLGUI/Well-Path-GUI/venv/lib/python3.10/site-packages/well_profile/load_trajectory.py:65: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/edwardblackman/WELLGUI/Well-Path-GUI/venv/lib/python3.10/site-packages/well_profile/load_trajectory.py:66: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/edwardblackman/WELLGUI/Well-Path-GUI/venv/lib/python3.10/site-packages/well_profile/load_trajectory.py:216: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/edwardblackman/WELLGUI/Well-Path-GUI/venv/lib/python3.10/site-packages/well_profile/load_trajectory.py:65: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/edwardblackman/WELLGUI/Well-Path-GUI/venv/lib/python3.10/site-packages/well_profile/load_trajectory.py:66: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/edwardblackman/WELLGUI/Well-Path-GUI/venv/lib/python3.10/site-packages/well_profile/load_trajectory.py:216: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="b34ec355-b61f-42eb-affa-28c31683c878" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b34ec355-b61f-42eb-affa-28c31683c878")) {                    Plotly.newPlot(                        "b34ec355-b61f-42eb-affa-28c31683c878",                        [{"hovertemplate":"well=Test\u003cbr\u003eeast=%{x}\u003cbr\u003enorth=%{y}\u003cbr\u003etvd=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Test","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Test","scene":"scene","showlegend":true,"x":[639978.6,639978.6,639989.9290536483,640012.5296803188,640079.687525565,640152.7942832458,640301.6247432844,640423.9438401775,640636.4957650242,640793.2737128066,641037.4130172115,641444.3118578861],"y":[5475924.5,5475924.5,5475917.959167827,5475904.910689935,5475866.137089904,5475823.928883677,5475738.0015775105,5475667.380613992,5475544.663702965,5475454.147912609,5475313.194019492,5475078.270864295],"z":[0.0,200.0,499.6193731861248,697.8454324134944,987.2555230305147,1168.2871037409313,1413.7209257949319,1554.9628528314463,1726.817465165278,1811.23387761845,1913.8399206161505,2084.8499922789847],"type":"scatter3d"},{"line":{"width":0},"marker":{"color":"red","size":10},"name":"Sample","x":[640032.2048122269,640037.221367611,640043.5920557295,640046.463477325,640055.466266362,640057.2572152794,640073.858385171,640110.6347179466,640131.0505465993,640143.3014420972,640157.8027445346,640167.7679469229,640183.4713574712,640194.6003252737,640212.0829100801,640237.6563183974,640241.997839793,640252.8495283247,640257.2924294136,640261.1312250241,640269.1925955641,640298.8462196925,640303.1298621993,640380.1697651881,640468.2184034525,640469.7928837737,640480.3079800282,640485.4193628666,640525.0564201401,640551.6156213062,640668.3219611676,640746.5282712005,640763.345345599,640799.7840942574,640803.8530826642,640882.2217993782,640932.4331163174,640942.1986884936],"y":[5475893.551247232,5475890.6549376305,5475886.97681913,5475885.319003099,5475880.121240425,5475879.087235586,5475869.50254568,5475848.269720052,5475836.482635884,5475829.40957807,5475821.037247204,5475815.283834923,5475806.217466615,5475799.792154059,5475789.698579014,5475774.933764839,5475772.427186293,5475766.161960998,5475763.596850857,5475761.380521178,5475756.726286727,5475739.605758854,5475737.1325966995,5475692.653587971,5475641.818682967,5475640.90965633,5475634.838762676,5475631.887704419,5475609.003238732,5475593.66927679,5475526.288840055,5475481.136405904,5475471.4270634735,5475450.389142126,5475448.039910574,5475402.793710884,5475373.804193532,5475368.166037807],"z":[806.1695163828634,829.2536345820329,856.787562178844,868.6322208251161,903.8284121801155,910.5159579366482,968.4222992794246,1074.169703135776,1122.4130539444766,1148.867467747265,1178.2270866742006,1197.5619194845904,1226.9117730629573,1246.944056618846,1277.2324942986945,1319.1788375364267,1326.043100696414,1342.89487575549,1349.6720944071292,1355.472219484816,1367.4884959925143,1409.886034500854,1415.7871992594912,1509.939923301342,1596.221975832099,1597.6307630771805,1606.9401913848033,1611.403927046945,1644.6977022303095,1665.7515482412002,1747.1462670620933,1790.02617116531,1798.0200648491098,1813.9700387650553,1815.6801394816837,1848.6166792839456,1869.7193221271393,1873.8235638470474],"type":"scatter3d"}],                        {"scene":{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"xaxis":{"title":{"text":"East, m"}},"yaxis":{"title":{"text":"North, m"}},"zaxis":{"title":{"text":"TVD, m"},"autorange":"reversed"},"aspectmode":"manual"},"legend":{"title":{"text":"well"},"tracegroupgap":0},"margin":{"t":60},"images":[{"sizex":0.2,"sizey":0.2,"source":"https:\u002f\u002favatars.git ...
#
# var gd = document.getElementById('b34ec355-b61f-42eb-affa-28c31683c878');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>
#           UWI  Surf-Hole Northing (NAD83)  Surf-Hole Easting (NAD83)  \
# 0   test-well                   5430075.3                   592761.9
# 1  test-well2                   5475924.5                   639978.6
#
#    Ground Elevation (m)                                               well
# 0                   565  <well_profile.well.Well object at 0x7fa6fc44f7f0>
# 1                   200  <well_profile.well.Well object at 0x7fa6c4366e00>              UWI    md  inclination  azi
# 0    test-well     0            0    0
# 1    test-well   100            0    0
# 2    test-well  1000            0    0
# 3    test-well  2000            0    0
# 4   test-well2     0            0    0
# 5   test-well2   200            0    0
# 6   test-well2   500            5  120
# 7   test-well2   700           10  120
# 8   test-well2  1000           20  120
# 9   test-well2  1200           30  120
# 10  test-well2  1500           40  120
# 11  test-well2  1700           50  120
# 12  test-well2  2000           60  120
# 13  test-well2  2200           70  120
# 14  test-well2  2500           70  120
# 15  test-well2  3000           70  120    Gas Analysis #         UWI  Interval Top(m)  Interval Base(m)  H2 Air Free  \
# 0               1   test-well              750               760     0.047600
# 1               2   test-well             1200              1210     0.060000
# 2               1  test-well2              200               210     0.176000
# 3               2  test-well2              566               573     0.222933
# 4               3  test-well2             1000              1005     0.287133
# 5               4  test-well2             1040              1045     0.351333
# 6               5  test-well2             1564              1573     0.149300
# 7               6  test-well2             2281              2291     0.209780
# 8               7  test-well2             2999              3000     0.209780
#
#    He Air Free  N2 Air Free  CO2 Air Free   sample_midpoint_depth  \
# 0     0.002300      0.34520       0.000500                  755.0
# 1     0.020000      0.40000       0.006000                 1205.0
# 2     0.197800      0.21960       0.241400                  205.0
# 3     0.268867      0.19600       0.323533                  569.5
# 4     0.366617      0.13320       0.443983                 1002.5
# 5     0.464367      0.07040       0.564433                 1042.5
# 6     0.169460      0.18962       0.209780                 1568.5
# 7     0.229940      0.25010       0.270260                 2286.0
# 8     0.229940      0.25010       0.270260                 2999.5
#
#            TVD        Easting      Northing  Ground Elevation  \
# 0   755.000000  592761.900000  5.430075e+06               565
# 1  1205.000000  592761.900000  5.430075e+06               565
# 2   204.999998  639978.603149  5.475924e+06               200
# 3   568.752456  639996.083119  5.475914e+06               200
# 4   989.603820  640080.430240  5.475866e+06               200
# 5  1026.913780  640092.914361  5.475859e+06               200
# 6  1464.848086  640341.091816  5.475715e+06               200
# 7  1840.647610  640863.260313  5.475414e+06               200
# 8  2084.678982  641443.904959  5.475079e+06               200
#
#    Sample Depth Below Sea Level
# 0                   -190.000000
# 1                   -640.000000
# 2                     -4.999998
# 3                   -368.752456
# 4                   -789.603820
# 5                   -826.913780
# 6                  -1264.848086
# 7                  -1640.647610
# 8                  -1884.678982              UWI DataType UnitFlag     FMName     FMCode          TVD      MD  \
# 0    test-well        T        M   Kmed_hat  164004000   598.200000   598.2
# 1    test-well        T        M    K2nd_ws  186004000   736.200000   736.2
# 2    test-well        T        M    Kcolo_L  201300000   793.400000   793.4
# 3    test-well        T        M   Kfish_sc  205804000   811.200000   811.2
# 4    test-well        T        M  Kwestgate  208004000   842.600000   842.6
# 5    test-well        T        M    Kvik_ss  218100000   909.200000   909.2
# 6    test-well        T        M   Kmed_hat  164004000   598.200000   598.2
# 7    test-well        T        M    K2nd_ws  186004000   736.200000   736.2
# 8    test-well        T        M    Kcolo_L  201300000   793.400000   793.4
# 9    test-well        T        M   Kfish_sc  205804000   811.200000   811.2
# 10   test-well        T        M  Kwestgate  208004000   842.600000   842.6
# 11   test-well        T        M    Kvik_ss  218100000   909.200000   909.2
# 12  test-well2        T        M    K2nd_ws  186004000   806.169516   810.7
# 13  test-well2        T        M    Kcolo_L  201300000   829.253635   834.5
# 14  test-well2        T        M   Kfish_sc  205804000   856.787562   863.0
# 15  test-well2        T        M  Kwestgate  208004000   868.632221   875.3
# 16  test-well2        T        M    Kvik_ss  218100000   903.828412   912.0
# 17  test-well2        T        M  Kjoli_fou  237060000   910.515958   919.0
# 18  test-well2        T        M    Kmannvl  248004000   968.422299   980.0
# 19  test-well2        T        M  Jvanguard  421000000  1074.169703  1094.0
# 20  test-well2        T        M  Jrier_mkr  425600000  1122.413054  1147.7
# 21  test-well2        T        M  Jshaunv_U  428320000  1148.867468  1177.7
# 22  test-well2        T        M  Jshaunv_L  432000000  1178.227087  1211.5
# 23  test-well2        T        M  Jgrvlbg_U  435200000  1197.561919  1234.0
# 24  test-well2        T        M  Jgrvlbg_L  435400000  1226.911773  1268.5
# 25  test-well2        T        M  Jwatrus_U  452000000  1246.944057  1292.3
# 26  test-well2        T        M  TRwatrs_L  500204000  1277.232494  1328.7
# 27  test-well2        T        M    Mpoplar  610400000  1319.178838  1380.0
# 28  test-well2        T        M    Mratclf  611000000  1326.043101  1388.5
# 29  test-well2        T        M  Mmidal_ev  626900000  1342.894876  1409.5
# 30  test-well2        T        M    Mmidale  627000000  1349.672094  1418.0
# 31  test-well2        T        M   Mfrob_ev  642190000  1355.472219  1425.3
# 32  test-well2        T        M  Mfrobishr  642200000  1367.488496  1440.5
# 33  test-well2        T        M    Mkisbey  642840000  1409.886035  1495.0
# 34  test-well2        T        M     Malida  643000000  1415.787199  1502.7
# 35  test-well2        T        M  Msouris_v  644020000  1509.939923  1632.3
# 36  test-well2        T        M  Mbakken_U  646520000  1596.221976  1765.7
# 37  test-well2        T        M  Mbakken_M  646540000  1597.630763  1768.0
# 38  test-well2        T        M  Mbakken_L  649000000  1606.940191  1783.3
# 39  test-well2        T        M   Dtorquay  666200000  1611.403927  1790.7
# 40  test-well2        T        M  Dbirdbear  679000000  1644.697702  1847.3
# 41  test-well2        T        M   Dduperow  711004000  1665.751548  1884.5
# 42  test-well2        T        M  Dsouris_r  747000000  1747.146267  2042.0
# 43  test-well2        T        M  D1red_bds  767000000  1790.026171  2142.0
# 44  test-well2        T        M  Ddawsonby  773004000  1798.020065  2163.0
# 45  test-well2        T        M  D2red_bds  780500000  1813.970039  2208.0
# 46  test-well2        T        M  Dprair_ev  782204000  1815.680139  2213.0
# 47  test-well2        T        M  Dwnpgosis  787004000  1848.616679  2309.3
# 48  test-well2        T        M    Dashern  793004000  1869.719322  2371.0
# 49  test-well2        T        M  Sintrlk_U  833020000  1873.823564  2383.0
#
#     Unnamed: 7        Easting      Northing  Ground Elevation  \
# 0          NaN  592761.900000  5.430075e+06               565
# 1          NaN  592761.900000  5.430075e+06               565
# 2          NaN  592761.900000  5.430075e+06               565
# 3          NaN  592761.900000  5.430075e+06               565
# 4          NaN  592761.900000  5.430075e+06               565
# 5          NaN  592761.900000  5.430075e+06               565
# 6          NaN  592761.900000  5.430075e+06               565
# 7          NaN  592761.900000  5.430075e+06               565
# 8          NaN  592761.900000  5.430075e+06               565
# 9          NaN  592761.900000  5.430075e+06               565
# 10         NaN  592761.900000  5.430075e+06               565
# 11         NaN  592761.900000  5.430075e+06               565
# 12         NaN  640032.204812  5.475894e+06               200
# 13         NaN  640037.221368  5.475891e+06               200
# 14         NaN  640043.592056  5.475887e+06               200
# 15         NaN  640046.463477  5.475885e+06               200
# 16         NaN  640055.466266  5.475880e+06               200
# 17         NaN  640057.257215  5.475879e+06               200
# 18         NaN  640073.858385  5.475870e+06               200
# 19         NaN  640110.634718  5.475848e+06               200
# 20         NaN  640131.050547  5.475836e+06               200
# 21         NaN  640143.301442  5.475829e+06               200
# 22         NaN  640157.802745  5.475821e+06               200
# 23         NaN  640167.767947  5.475815e+06               200
# 24         NaN  640183.471357  5.475806e+06               200
# 25         NaN  640194.600325  5.475800e+06               200
# 26         NaN  640212.082910  5.475790e+06               200
# 27         NaN  640237.656318  5.475775e+06               200
# 28         NaN  640241.997840  5.475772e+06               200
# 29         NaN  640252.849528  5.475766e+06               200
# 30         NaN  640257.292429  5.475764e+06               200
# 31         NaN  640261.131225  5.475761e+06               200
# 32         NaN  640269.192596  5.475757e+06               200
# 33         NaN  640298.846220  5.475740e+06               200
# 34         NaN  640303.129862  5.475737e+06               200
# 35         NaN  640380.169765  5.475693e+06               200
# 36         NaN  640468.218403  5.475642e+06               200
# 37         NaN  640469.792884  5.475641e+06               200
# 38         NaN  640480.307980  5.475635e+06               200
# 39         NaN  640485.419363  5.475632e+06               200
# 40         NaN  640525.056420  5.475609e+06               200
# 41         NaN  640551.615621  5.475594e+06               200
# 42         NaN  640668.321961  5.475526e+06               200
# 43         NaN  640746.528271  5.475481e+06               200
# 44         NaN  640763.345346  5.475471e+06               200
# 45         NaN  640799.784094  5.475450e+06               200
# 46         NaN  640803.853083  5.475448e+06               200
# 47         NaN  640882.221799  5.475403e+06               200
# 48         NaN  640932.433116  5.475374e+06               200
# 49         NaN  640942.198688  5.475368e+06               200
#
#     Sample Depth Below Sea Level
# 0                     -33.200000
# 1                    -171.200000
# 2                    -228.400000
# 3                    -246.200000
# 4                    -277.600000
# 5                    -344.200000
# 6                     -33.200000
# 7                    -171.200000
# 8                    -228.400000
# 9                    -246.200000
# 10                   -277.600000
# 11                   -344.200000
# 12                   -606.169516
# 13                   -629.253635
# 14                   -656.787562
# 15                   -668.632221
# 16                   -703.828412
# 17                   -710.515958
# 18                   -768.422299
# 19                   -874.169703
# 20                   -922.413054
# 21                   -948.867468
# 22                   -978.227087
# 23                   -997.561919
# 24                  -1026.911773
# 25                  -1046.944057
# 26                  -1077.232494
# 27                  -1119.178838
# 28                  -1126.043101
# 29                  -1142.894876
# 30                  -1149.672094
# 31                  -1155.472219
# 32                  -1167.488496
# 33                  -1209.886035
# 34                  -1215.787199
# 35                  -1309.939923
# 36                  -1396.221976
# 37                  -1397.630763
# 38                  -1406.940191
# 39                  -1411.403927
# 40                  -1444.697702
# 41                  -1465.751548
# 42                  -1547.146267
# 43                  -1590.026171
# 44                  -1598.020065
# 45                  -1613.970039
# 46                  -1615.680139
# 47                  -1648.616679
# 48                  -1669.719322
# 49                  -1673.823564
