# %%
import Point_XYZ_Package as xyz

def main():
  # GUI data import
  collar_data, survey_data, sample_data, geology_data = xyz.main()

  # Data stuff, manipulation, calculations etc
  surveys = xyz.import_survey(survey_data)
  collars = xyz.import_collar(collar_data, surveys)  
  samples = xyz.import_sample(sample_data, collars)
  tops = xyz.import_geology(geology_data, collars)

  # Plotting
  xyz.plot(collars, tops)
  # Saving
  print(collars, surveys, samples, tops)
  return collars, surveys, samples, tops
  

if __name__ == "__main__":
    main()
# Out:
#           UWI  Surf-Hole Northing (NAD83)  Surf-Hole Easting (NAD83)  \
# 0   test-well                   5430075.3                   592761.9
# 1  test-well2                   5475924.5                   639978.6
#
#    Ground Elevation (m)                                               well
# 0                   565  <well_profile.well.Well object at 0x7faed124b910>
# 1                   200  <well_profile.well.Well object at 0x7faed124a830>              UWI       md      tvd  inclination   azi
# 0    test-well     0.00     0.00          0.0   0.0
# 1    test-well   100.00   100.00          0.0   0.0
# 2    test-well  1000.00  1000.00          0.0   0.0
# 3    test-well  2000.00  2000.00          0.0   0.0
# 4   test-well2     0.00     0.00          0.0   0.0
# ..         ...      ...      ...          ...   ...
# 82  test-well2  1774.63  1121.55         89.7  88.7
# 83  test-well2  1787.00  1121.56         90.2  89.3
# 84  test-well2  1803.00  1121.50         90.2  89.3
# 85  test-well2  1804.00  1804.00          0.0   0.0
# 86  test-well2  3000.00  3000.00          0.0   0.0
#
# [87 rows x 5 columns]    Gas Analysis #         UWI  Interval Top(m)  Interval Base(m)  H2 Air Free  \
# 0               1   test-well              750               760     0.047600
# 1               2   test-well             1200              1210     0.060000
# 2               1  test-well2              200               210     0.176000
# 3               2  test-well2              566               573     0.222933
# 4               3  test-well2             1000              1005     0.287133
# 5               4  test-well2             1040              1045     0.351333
# 6               5  test-well2             1564              1573     0.149300
# 7               6  test-well2             2281              2291     0.209780
# 8               7  test-well2             2999              3000     0.209780
#
#    He Air Free  N2 Air Free  CO2 Air Free   sample_midpoint_depth  \
# 0     0.002300      0.34520       0.000500                  755.0
# 1     0.020000      0.40000       0.006000                 1205.0
# 2     0.197800      0.21960       0.241400                  205.0
# 3     0.268867      0.19600       0.323533                  569.5
# 4     0.366617      0.13320       0.443983                 1002.5
# 5     0.464367      0.07040       0.564433                 1042.5
# 6     0.169460      0.18962       0.209780                 1568.5
# 7     0.229940      0.25010       0.270260                 2286.0
# 8     0.229940      0.25010       0.270260                 2999.5
#
#            TVD        Easting      Northing  Ground Elevation  \
# 0   755.000000  592761.900000  5.430075e+06               565
# 1  1205.000000  592761.900000  5.430075e+06               565
# 2   204.999171  639978.927327  5.475924e+06               200
# 3   569.409821  639973.942848  5.475920e+06               200
# 4  1000.686817  639991.982490  5.475914e+06               200
# 5  1035.976547  640010.169400  5.475910e+06               200
# 6  1119.593332  640501.792302  5.475862e+06               200
# 7  1604.135908  640736.720762  5.475869e+06               200
# 8  2317.635908  640736.720762  5.475869e+06               200
#
#    Sample Depth Below Sea Level
# 0                   -190.000000
# 1                   -640.000000
# 2                     -4.999171
# 3                   -369.409821
# 4                   -800.686817
# 5                   -835.976547
# 6                   -919.593332
# 7                  -1404.135908
# 8                  -2117.635908              UWI DataType UnitFlag     FMName     FMCode          TVD      MD  \
# 0    test-well        T        M   Kmed_hat  164004000   598.200000   598.2
# 1    test-well        T        M    K2nd_ws  186004000   736.200000   736.2
# 2    test-well        T        M    Kcolo_L  201300000   793.400000   793.4
# 3    test-well        T        M   Kfish_sc  205804000   811.200000   811.2
# 4    test-well        T        M  Kwestgate  208004000   842.600000   842.6
# 5    test-well        T        M    Kvik_ss  218100000   909.200000   909.2
# 6    test-well        T        M   Kmed_hat  164004000   598.200000   598.2
# 7    test-well        T        M    K2nd_ws  186004000   736.200000   736.2
# 8    test-well        T        M    Kcolo_L  201300000   793.400000   793.4
# 9    test-well        T        M   Kfish_sc  205804000   811.200000   811.2
# 10   test-well        T        M  Kwestgate  208004000   842.600000   842.6
# 11   test-well        T        M    Kvik_ss  218100000   909.200000   909.2
# 12  test-well2        T        M    K2nd_ws  186004000   810.565550   810.7
# 13  test-well2        T        M    Kcolo_L  201300000   834.364367   834.5
# 14  test-well2        T        M   Kfish_sc  205804000   862.863267   863.0
# 15  test-well2        T        M  Kwestgate  208004000   875.162845   875.3
# 16  test-well2        T        M    Kvik_ss  218100000   911.861537   912.0
# 17  test-well2        T        M  Kjoli_fou  237060000   918.860955   919.0
# 18  test-well2        T        M    Kmannvl  248004000   979.109920   980.0
# 19  test-well2        T        M  Jvanguard  421000000  1075.100832  1094.0
# 20  test-well2        T        M  Jrier_mkr  425600000  1103.894434  1147.7
# 21  test-well2        T        M  Jshaunv_U  428320000  1113.076054  1177.7
# 22  test-well2        T        M  Jshaunv_L  432000000  1119.411990  1211.5
# 23  test-well2        T        M  Jgrvlbg_U  435200000  1120.867264  1234.0
# 24  test-well2        T        M  Jgrvlbg_L  435400000  1121.905958  1268.5
# 25  test-well2        T        M  Jwatrus_U  452000000  1122.428558  1292.3
# 26  test-well2        T        M  TRwatrs_L  500204000  1122.616358  1328.7
# 27  test-well2        T        M    Mpoplar  610400000  1120.929168  1380.0
# 28  test-well2        T        M    Mratclf  611000000  1120.747669  1388.5
# 29  test-well2        T        M  Mmidal_ev  626900000  1120.260144  1409.5
# 30  test-well2        T        M    Mmidale  627000000  1120.304376  1418.0
# 31  test-well2        T        M   Mfrob_ev  642190000  1120.038883  1425.3
# 32  test-well2        T        M  Mfrobishr  642200000  1119.749019  1440.5
# 33  test-well2        T        M    Mkisbey  642840000  1120.457454  1495.0
# 34  test-well2        T        M     Malida  643000000  1120.520268  1502.7
# 35  test-well2        T        M  Msouris_v  644020000  1118.625183  1632.3
# 36  test-well2        T        M  Mbakken_U  646520000  1121.504325  1765.7
# 37  test-well2        T        M  Mbakken_M  646540000  1121.513979  1768.0
# 38  test-well2        T        M  Mbakken_L  649000000  1121.572274  1783.3
# 39  test-well2        T        M   Dtorquay  666200000  1121.543638  1790.7
# 40  test-well2        T        M  Dbirdbear  679000000  1165.435908  1847.3
# 41  test-well2        T        M   Dduperow  711004000  1202.635908  1884.5
# 42  test-well2        T        M  Dsouris_r  747000000  1360.135908  2042.0
# 43  test-well2        T        M  D1red_bds  767000000  1460.135908  2142.0
# 44  test-well2        T        M  Ddawsonby  773004000  1481.135908  2163.0
# 45  test-well2        T        M  D2red_bds  780500000  1526.135908  2208.0
# 46  test-well2        T        M  Dprair_ev  782204000  1531.135908  2213.0
# 47  test-well2        T        M  Dwnpgosis  787004000  1627.435908  2309.3
# 48  test-well2        T        M    Dashern  793004000  1689.135908  2371.0
# 49  test-well2        T        M  Sintrlk_U  833020000  1701.135908  2383.0
#
#     Unnamed: 7        Easting      Northing  Ground Elevation  \
# 0          NaN  592761.900000  5.430075e+06               565
# 1          NaN  592761.900000  5.430075e+06               565
# 2          NaN  592761.900000  5.430075e+06               565
# 3          NaN  592761.900000  5.430075e+06               565
# 4          NaN  592761.900000  5.430075e+06               565
# 5          NaN  592761.900000  5.430075e+06               565
# 6          NaN  592761.900000  5.430075e+06               565
# 7          NaN  592761.900000  5.430075e+06               565
# 8          NaN  592761.900000  5.430075e+06               565
# 9          NaN  592761.900000  5.430075e+06               565
# 10         NaN  592761.900000  5.430075e+06               565
# 11         NaN  592761.900000  5.430075e+06               565
# 12         NaN  639976.558964  5.475917e+06               200
# 13         NaN  639976.778123  5.475916e+06               200
# 14         NaN  639976.978989  5.475916e+06               200
# 15         NaN  639977.044948  5.475916e+06               200
# 16         NaN  639977.172192  5.475916e+06               200
# 17         NaN  639977.236681  5.475916e+06               200
# 18         NaN  639985.730637  5.475915e+06               200
# 19         NaN  640042.826508  5.475904e+06               200
# 20         NaN  640086.836535  5.475894e+06               200
# 21         NaN  640114.542263  5.475887e+06               200
# 22         NaN  640146.655883  5.475879e+06               200
# 23         NaN  640168.412267  5.475874e+06               200
# 24         NaN  640202.218081  5.475867e+06               200
# 25         NaN  640225.894178  5.475865e+06               200
# 26         NaN  640250.131054  5.475864e+06               200
# 27         NaN  640302.430149  5.475862e+06               200
# 28         NaN  640315.500541  5.475862e+06               200
# 29         NaN  640341.635533  5.475860e+06               200
# 30         NaN  640341.639913  5.475860e+06               200
# 31         NaN  640354.702309  5.475859e+06               200
# 32         NaN  640367.786689  5.475858e+06               200
# 33         NaN  640428.391672  5.475859e+06               200
# 34         NaN  640436.086132  5.475859e+06               200
# 35         NaN  640563.981133  5.475864e+06               200
# 36         NaN  640698.788224  5.475868e+06               200
# 37         NaN  640701.087966  5.475868e+06               200
# 38         NaN  640707.715997  5.475868e+06               200
# 39         NaN  640723.784377  5.475869e+06               200
# 40         NaN  640736.720762  5.475869e+06               200
# 41         NaN  640736.720762  5.475869e+06               200
# 42         NaN  640736.720762  5.475869e+06               200
# 43         NaN  640736.720762  5.475869e+06               200
# 44         NaN  640736.720762  5.475869e+06               200
# 45         NaN  640736.720762  5.475869e+06               200
# 46         NaN  640736.720762  5.475869e+06               200
# 47         NaN  640736.720762  5.475869e+06               200
# 48         NaN  640736.720762  5.475869e+06               200
# 49         NaN  640736.720762  5.475869e+06               200
#
#     Sample Depth Below Sea Level
# 0                     -33.200000
# 1                    -171.200000
# 2                    -228.400000
# 3                    -246.200000
# 4                    -277.600000
# 5                    -344.200000
# 6                     -33.200000
# 7                    -171.200000
# 8                    -228.400000
# 9                    -246.200000
# 10                   -277.600000
# 11                   -344.200000
# 12                   -610.565550
# 13                   -634.364367
# 14                   -662.863267
# 15                   -675.162845
# 16                   -711.861537
# 17                   -718.860955
# 18                   -779.109920
# 19                   -875.100832
# 20                   -903.894434
# 21                   -913.076054
# 22                   -919.411990
# 23                   -920.867264
# 24                   -921.905958
# 25                   -922.428558
# 26                   -922.616358
# 27                   -920.929168
# 28                   -920.747669
# 29                   -920.260144
# 30                   -920.304376
# 31                   -920.038883
# 32                   -919.749019
# 33                   -920.457454
# 34                   -920.520268
# 35                   -918.625183
# 36                   -921.504325
# 37                   -921.513979
# 38                   -921.572274
# 39                   -921.543638
# 40                   -965.435908
# 41                  -1002.635908
# 42                  -1160.135908
# 43                  -1260.135908
# 44                  -1281.135908
# 45                  -1326.135908
# 46                  -1331.135908
# 47                  -1427.435908
# 48                  -1489.135908
# 49                  -1501.135908
# /home/edwardblackman/WELLGUI/Well-Path-GUI/venv/lib/python3.10/site-packages/well_profile/load_trajectory.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(axis=1, how='all', inplace=True)
# /home/edwardblackman/WELLGUI/Well-Path-GUI/venv/lib/python3.10/site-packages/well_profile/load_trajectory.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
# /home/edwardblackman/WELLGUI/Well-Path-GUI/venv/lib/python3.10/site-packages/well_profile/load_trajectory.py:216: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns={x: correct_keys[true_key]}, inplace=True)
# /home/edwardblackman/WELLGUI/Well-Path-GUI/venv/lib/python3.10/site-packages/well_profile/load_trajectory.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(axis=1, how='all', inplace=True)
# /home/edwardblackman/WELLGUI/Well-Path-GUI/venv/lib/python3.10/site-packages/well_profile/load_trajectory.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
# /home/edwardblackman/WELLGUI/Well-Path-GUI/venv/lib/python3.10/site-packages/well_profile/load_trajectory.py:216: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns={x: correct_keys[true_key]}, inplace=True)
